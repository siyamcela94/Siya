# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Siyamcelamafanya051"
)

print(mydb)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Siyamcelamafanya051"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE mydata")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="Siyamcelamafanya051",
  db="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mydata',)
# ('mydatabase',)
# ('mysql',)
# ('new_schema',)
# ('performance_schema',)
# ('sprint',)
# ('sprint3',)
# ('sys',)

# %%
import pandas as pd
df= pd.read_sql_query("Select * from data", mydb)
df
# Out:
#     Chips,  Quantity,  price,  Cooldrinks,  Quantity,_[0] price,_[0]  \
# 0    Simba         50  R65.00         Coke             24       R216
# 1     Lays         50  R70.00        Fanta             12       R108
# 2  Doritos         50  R70.00       Sprite             12       R108
# 3    Bigga         50  R40.00       Stoney             12       R108
# 4   Flyers         50  R38.00  Lemon Twist             12       R108
#
#   Chocolates,  Quantity,_[1] price,_[1]           Pies,  ...  price,_[2]  \
# 0     Cadbury             30        R25    Pepper Steak  ...         R12
# 1         Tex             30        R25         Chicken  ...         R12
# 2   Lunch Bar             30        R32  Steak & kidney  ...         R12
# 3     One Bar             30        R32         mashrom  ...         R12
# 4         P.S             30                     Masala  ...         R12
#
#     Fruit ,Quantity,  price,_[3]   Cupcakes, Quantity,_[3]  price,_[4]  \
# ...

# %%
#Adding column
mycursor.execute("Alter table data Add Barcode VARCHAR(50)")

# %%
df= pd.read_sql_query("Select * from data", mydb)
df
# Out:
#     Chips,  Quantity,  price,  Cooldrinks,  Quantity,_[0] price,_[0]  \
# 0    Simba         50  R65.00         Coke             24       R216
# 1     Lays         50  R70.00        Fanta             12       R108
# 2  Doritos         50  R70.00       Sprite             12       R108
# 3    Bigga         50  R40.00       Stoney             12       R108
# 4   Flyers         50  R38.00  Lemon Twist             12       R108
#
#   Chocolates,  Quantity,_[1] price,_[1]           Pies,  ...   Fruit  \
# 0     Cadbury             30        R25    Pepper Steak  ...    Pear
# 1         Tex             30        R25         Chicken  ...   Apple
# 2   Lunch Bar             30        R32  Steak & kidney  ...    Pear
# 3     One Bar             30        R32         mashrom  ...   Peach
# 4         P.S             30                     Masala  ...  Orange
#
#   ,Quantity, price,_[3]   Cupcakes, Quantity,_[3] price,_[4]  Veggies,  \
# ...

# %%
#Updating table
sql="Update data set Barcode='123456' where `veggies,`='Spinach'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
df= pd.read_sql_query("Select * from data", mydb)
df
# Out:
#     Chips,  Quantity,  price,  Cooldrinks,  Quantity,_[0] price,_[0]  \
# 0    Simba         50  R65.00         Coke             24       R216
# 1     Lays         50  R70.00        Fanta             12       R108
# 2  Doritos         50  R70.00       Sprite             12       R108
# 3    Bigga         50  R40.00       Stoney             12       R108
# 4   Flyers         50  R38.00  Lemon Twist             12       R108
#
#   Chocolates,  Quantity,_[1] price,_[1]           Pies,  ...   Fruit  \
# 0     Cadbury             30        R25    Pepper Steak  ...    Pear
# 1         Tex             30        R25         Chicken  ...   Apple
# 2   Lunch Bar             30        R32  Steak & kidney  ...    Pear
# 3     One Bar             30        R32         mashrom  ...   Peach
# 4         P.S             30                     Masala  ...  Orange
#
#   ,Quantity, price,_[3]   Cupcakes, Quantity,_[3] price,_[4]  Veggies,  \
# ...

# %%
sql="Update data set Barcode='145256' where `veggies,`='cabbige'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
df= pd.read_sql_query("Select * from data", mydb)
df
# Out:
#     Chips,  Quantity,  price,  Cooldrinks,  Quantity,_[0] price,_[0]  \
# 0    Simba         50  R65.00         Coke             24       R216
# 1     Lays         50  R70.00        Fanta             12       R108
# 2  Doritos         50  R70.00       Sprite             12       R108
# 3    Bigga         50  R40.00       Stoney             12       R108
# 4   Flyers         50  R38.00  Lemon Twist             12       R108
#
#   Chocolates,  Quantity,_[1] price,_[1]           Pies,  ...   Fruit  \
# 0     Cadbury             30        R25    Pepper Steak  ...    Pear
# 1         Tex             30        R25         Chicken  ...   Apple
# 2   Lunch Bar             30        R32  Steak & kidney  ...    Pear
# 3     One Bar             30        R32         mashrom  ...   Peach
# 4         P.S             30                     Masala  ...  Orange
#
#   ,Quantity, price,_[3]   Cupcakes, Quantity,_[3] price,_[4]  Veggies,  \
# ...

# %%
df= pd.read_sql_query("Select `chips,`,`Quantity,`, `price,` from data", mydb)
df
# Out:
#     chips,  Quantity,  price,
# 0    Simba         50  R65.00
# 1     Lays         50  R70.00
# 2  Doritos         50  R70.00
# 3    Bigga         50  R40.00
# 4   Flyers         50  R38.00

# %%
#Filtering cooldrinks
df= pd.read_sql_query("Select `cooldrinks,`,`Quantity,_[0]`, `price,_[0]` from data", mydb)
df=df.to_csv("cooldrinks.csv",index = False)
df=pd.read_csv("cooldrinks.csv")
df
# Out:
#    cooldrinks,  Quantity,_[0] price,_[0]
# 0         Coke             24       R216
# 1        Fanta             12       R108
# 2       Sprite             12       R108
# 3       Stoney             12       R108
# 4  Lemon Twist             12       R108

# %%
#Inserting
sql = "INSERT INTO cooldrinks(`cooldrinks,`, `Quantity,_[0]`) VALUES (%s, %s)"
val = ("Twizza", 12)
mycursor.execute(sql, val)
mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
df= pd.read_sql_query("Select * from cooldrinks", mydb)
df
# Out:
#    cooldrinks,  Quantity,_[0] price,_[0]
# 0         Coke             24       R216
# 1        Fanta             12       R108
# 2       Sprite             12       R108
# 3       Stoney             12       R108
# 4  Lemon Twist             12       R108
# 5       Twizza             12       None

# %%
#Updating
sql = "UPDATE cooldrinks SET `price,_[0]` = 20  WHERE `cooldrinks,` = 'Twizza'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
df= pd.read_sql_query("Select * from cooldrinks", mydb)
df
# Out:
#    cooldrinks,  Quantity,_[0] price,_[0]
# 0         Coke             24       R216
# 1        Fanta             12       R108
# 2       Sprite             12       R108
# 3       Stoney             12       R108
# 4  Lemon Twist             12       R108
# 5       Twizza             12         20

# %%
#Deleting
sql = "DELETE FROM cooldrinks WHERE `cooldrinks,` = 'Twizza'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
df= pd.read_sql_query("Select * from cooldrinks", mydb)
df
# Out:
#    cooldrinks,  Quantity,_[0] price,_[0]
# 0         Coke             24       R216
# 1        Fanta             12       R108
# 2       Sprite             12       R108
# 3       Stoney             12       R108
# 4  Lemon Twist             12       R108
