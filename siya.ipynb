# %%
import pandas as pd
df = pd.read_csv("Data_Valt.csv")
df
# Out:
#      Chips  Quantity   price   Cooldrinks  Quantity.1 price.1 Chocolates  \
# 0    Simba        50  R65.00         Coke          24    R216    Cadbury
# 1     Lays        50  R70.00        Fanta          12    R108        Tex
# 2  Doritos        50  R70.00       Sprite          12    R108  Lunch Bar
# 3    Bigga        50  R40.00       Stoney          12    R108    One Bar
# 4   Flyers        50  R38.00  Lemon Twist          12    R108        P.S
#
#    Quantity.2 price.2            Pies  ...  price.3   Fruit Quantity.4  \
# 0          30     R25    Pepper Steak  ...      R12    Pear        100
# 1          30     R25         Chicken  ...      R12   Apple        100
# 2          30     R32  Steak & kidney  ...      R12    Pear        100
# 3          30     R32         mashrom  ...      R12   Peach        100
# 4          30     NaN          Masala  ...      R12  Orange        100
#
#    price.4    Cupcakes Quantity.5  price.5   Veggies Quantity.6  price.6
# ...

# %%
df = pd.read_csv("Data_Valt.csv")
df.filter(items=['Chips', 'Cooldrinks', 'Pies'])
# Out:
#      Chips   Cooldrinks            Pies
# 0    Simba         Coke    Pepper Steak
# 1     Lays        Fanta         Chicken
# 2  Doritos       Sprite  Steak & kidney
# 3    Bigga       Stoney         mashrom
# 4   Flyers  Lemon Twist          Masala
